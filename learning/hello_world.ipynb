# %% [markdown]
# # Hello World
#
# A starter notebook for IML modules.

# %%
print("Hello, world!")

# %% [markdown]
# ## Quick sanity check
#
# Verify the core data/ML libraries are available.

# %%
import sys
import numpy as np
import pandas as pd
import sklearn

print(f"Python  : {sys.version.split()[0]}")
print(f"numpy   : {np.__version__}")
print(f"pandas  : {pd.__version__}")
print(f"sklearn : {sklearn.__version__}")

# %%
df = pd.DataFrame({
    "user": ["A", "B", "C"],
    "login_attempts": [3, 25, 1],
    "label": ["Normal", "Suspicious", "Normal"],
})
df
